# %% [markdown]
# <a href="https://colab.research.google.com/github/mchlhrrmnn/ma1a/blob/main/Hallo_Welt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Das erste Colab-Notebook

# %%
print("Hallo Welt!")
# Out:
# Hallo Welt!

# %%
# prompt: lese alle daten aus der TEST.CSV in einen df ein

import pandas as pd

# Lies die CSV-Datei in einen Pandas DataFrame ein
df = pd.read_csv('https://raw.githubusercontent.com/mchlhrrmnn/ma1a/refs/heads/main/HundKatzeMaus.csv')

# Gib den DataFrame aus (optional)
df
# Out:
#     Name  Anzahl
# 0   Hund       1
# 1  Katze       2
# 2   Maus       3

# %%
# @title Distribution of Animal Types

import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame
plt.figure(figsize=(8, 6))
plt.bar(df['Name'], df['Anzahl'])
plt.xlabel('Animal Type')
plt.ylabel('Frequency')
_ = plt.title('Distribution of Animal Types')
